# %% [markdown]
# # ModernBERT DAPT
# Pretrain only on unlabelled text, excluding evaluation projects in strict mode.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-dapt",
        "--train",
        "/kaggle/input/domain-corpus/unlabelled.parquet",
        "--config",
        "configs/models/modernbert_dapt.yaml",
        "--output-dir",
        "/kaggle/working/outputs/dapt",
    ],
    check=True,
)
