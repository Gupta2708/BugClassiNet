# %% [markdown]
# # Stage 1 TF-IDF
# Run the reusable baseline trainer.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-tfidf",
        "--data-dir",
        "/kaggle/input/bugclassinet-nlbse-v1",
        "--output-dir",
        "/kaggle/working/outputs/tfidf",
    ],
    check=True,
)
print("Metrics saved under /kaggle/working/outputs/tfidf")
