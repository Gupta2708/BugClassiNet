# %% [markdown]
# # Prepare and audit
# Detect Kaggle inputs and invoke the package preparation CLI.

# %%
import os
import platform
import subprocess

print(platform.platform())
print(os.listdir("/kaggle/input"))
subprocess.run(["pip", "install", "-e", "."], check=True)
# subprocess.run(['python','-m','bugclassinet.cli','prepare-nlbse',...], check=True)
print("Outputs: /kaggle/working/outputs")
