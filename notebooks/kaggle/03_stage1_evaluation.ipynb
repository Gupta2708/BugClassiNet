# %% [markdown]
# # Stage 1 evaluation
# Evaluate an explicit saved model and report metrics.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "evaluate-stage1",
        "--model",
        "/kaggle/input/deberta-stage1-model/model",
        "--data",
        "/kaggle/input/bugclassinet-nlbse-v1/validation_clean.parquet",
        "--output-dir",
        "/kaggle/working/outputs/deberta_stage1_report",
    ],
    check=True,
)
