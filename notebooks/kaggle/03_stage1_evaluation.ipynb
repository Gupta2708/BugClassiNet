# %% [markdown]
# # Stage 1 evaluation
# Evaluate an explicit saved model and report metrics.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "evaluate-stage1",
        "--model-path",
        "/kaggle/working/outputs/tfidf/model.joblib",
        "--test",
        "/kaggle/input/bugclassinet-nlbse-v1/test.parquet",
        "--output-dir",
        "/kaggle/working/outputs/evaluation",
    ],
    check=True,
)
