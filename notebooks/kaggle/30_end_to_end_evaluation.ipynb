# %% [markdown]
# # End-to-end evaluation
# Evaluate an exported hierarchy prediction table.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "evaluate-hierarchy",
        "--test",
        "/kaggle/working/outputs/predictions.parquet",
        "--output-dir",
        "/kaggle/working/outputs",
    ],
    check=True,
)
