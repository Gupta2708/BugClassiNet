# %% [markdown]
# # Stage 2 DAPT ModernBERT
# Fine-tune Stage 2 from the DAPT checkpoint.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-stage2",
        "--data-dir",
        "/kaggle/input/mandelbugs",
        "--checkpoint",
        "/kaggle/working/outputs/dapt",
        "--output-dir",
        "/kaggle/working/outputs/stage2_dapt",
    ],
    check=True,
)
