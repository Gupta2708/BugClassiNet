# %% [markdown]
# # Stage 3 ModernBERT
# Train a fresh ARB/NAM head from the Stage 2 checkpoint.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-stage3",
        "--data-dir",
        "/kaggle/input/mandelbugs",
        "--checkpoint",
        "/kaggle/working/outputs/stage2",
        "--output-dir",
        "/kaggle/working/outputs/stage3",
    ],
    check=True,
)
