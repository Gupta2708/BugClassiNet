# %% [markdown]
# # Stage 3 DAPT ModernBERT
# Fine-tune Stage 3 from the DAPT Stage 2 checkpoint.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-stage3",
        "--data-dir",
        "/kaggle/input/mandelbugs",
        "--checkpoint",
        "/kaggle/working/outputs/stage2_dapt",
        "--output-dir",
        "/kaggle/working/outputs/stage3_dapt",
    ],
    check=True,
)
