# %% [markdown]
# # Stage 2 ModernBERT
# Train BOH/MAN from Mandelbugs Parquet files.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-stage2",
        "--data-dir",
        "/kaggle/input/mandelbugs",
        "--config",
        "configs/models/modernbert_stage2.yaml",
        "--output-dir",
        "/kaggle/working/outputs/stage2",
    ],
    check=True,
)
