# %% [markdown]
# # Stage 1 DeBERTa
# Run configurable Transformer training; Kaggle GPU is detected by Transformers.

# %%
import subprocess

subprocess.run(
    [
        "python",
        "-m",
        "bugclassinet.cli",
        "train-stage1",
        "--data-dir",
        "/kaggle/input/bugclassinet-nlbse-v1",
        "--config",
        "configs/models/deberta_stage1.yaml",
        "--output-dir",
        "/kaggle/working/outputs/stage1",
    ],
    check=True,
)
