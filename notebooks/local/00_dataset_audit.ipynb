# %% [markdown]
# # Dataset audit
# Inspect a prepared dataset using package APIs.

# %%
from bugclassinet.data.validate import validate_parquet

frame = validate_parquet("data/processed/nlbse2023/train.parquet")
frame.head()
