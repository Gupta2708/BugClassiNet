# %% [markdown]
# # Error analysis
# Inspect saved prediction artifacts with package utilities.

# %%
import pandas as pd

from bugclassinet.evaluation.error_analysis import misclassifications

misclassifications(pd.read_parquet("outputs/predictions/predictions.parquet")).head()
